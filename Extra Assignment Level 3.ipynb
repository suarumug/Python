# %%
# print 'CORRECT' if i == 10
i=int(input("Value:"))
if(i == 10):
    print("Correct")
else:
    print("Not Correct")
# Out:
# Value: 10
# Correct

# %%
pwd=input("Enter the password:")
if (pwd == 'HOPE@123'):
    print("Your password is correct")
else:
    print("Your password is NOT correct")
# Out:
# Enter the password: HOPE@123
# Your password is correct

# %%
# category the people by their age like children,adult,citizen, senior citizen 
age = int(input("age:"))
if age < 19:
    print("Children")
elif age <35:
    print("Adult")
elif age <54:
    print("Citizen")
else:
    print("Senior Citizens")
# Out:
# age: 20
# Adult

# %%
# Find given number is positive or Negative 
num = int(input("Enter any number"))
if num > 0:
    print( num, "is positive")
elif num < 0:
  print( num, "is negative")
# Out:
# Enter any number 1
# 1 is positive

# %%
# check whether the given number is divisible by 5 
div=int(input("Enter a number to check:"))
if div % 5 == 0:
    print( div,"is divisible by 5")
else:
    print( div,"is NOT divisible by 5")
# Out:
# Enter a number to check: 22
# 22 is NOT divisible by 5
