# %%
from Class2Assignment import Class2AssignmentFromFile

# %%
Class2AssignmentFromFile.SubFields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
Result1=Class2AssignmentFromFile.OddEven()
# Out:
# Enter a number: 87
# 87 is a Odd Number

# %%
Result2=Class2AssignmentFromFile.MarriageEligibility()
# Out:
# Your Gender: Male
# your age: 20
# NOT ELIGIBLE

# %%
Result3=Class2AssignmentFromFile.Percentage()
# Out:
# Subject1: 98
# Subject2: 87
# Subject3: 95
# Subject4: 95
# Subject5: 93
# Total: 468
# Percentage: 93.60000000000001

# %%
Result4=Class2AssignmentFromFile.triangle()
# Out:
# Height: 32
# Breadth: 34
# Area Formula: (Height*Breadth)/2
# Area of Triagle: 544.0
# Height1: 2
# Height2: 4
# Breadth1: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triagle: 10.0
