# %%
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)

# %%
#1: Corrected code- : is missing in for loop 
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

# %%
#2 - Corrected Code- Python cannot add 2 different data types 
a = 10
b = "5"
print(a + int(b))
# or 
print(str(a) + b)
# Out:
# 15
# 105

# %%
#3.What is the issue in this Python snippet?

 def add_numbers(a, b)
    return a + b

# %%
#3.Corrected Code - : missing in Function definition
def add_numbers(a, b):
    return a + b
add_numbers(6, 7)
# Out:
# 13

# %%
#4.Identify the bug in the following Python code:

 numbers = [1, 2, 3, 4]
print(numbers[4])

# %%
#4 Corrected Code- Available total index is 3 as index in given list starts from 0
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
#5.Find the error in the following Python code:
print "Hello, World!"

# %%
#5 - Corrected Code - Parenthesis is missing for print function
print ("Hello, World!")
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# %%
#6: Corrected Code - Divisible by 0 is error 
x = 5 / 1
print (int(x))
print(x)
# Out:
# 5
# 5.0

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# %%
#7 Concatenation works for same data type. So converted age to str 
name = "Alice"
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#8.Corrected Code - Step value is not in the range of start and stop 
for i in range(1, 10, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#9. corrected code -  Assignment operator should be == and else statement is missing 
x = 10
if x == 5:
    print("x is 5")
else:
    print("x is not 5. X is ",x)
# Out:
# x is not 5. X is  10

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)

# %%
#10.Corrected code - Def : is missing 

def greet(name):
    print("Hello, " + name)
    
greet(AI)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       3 def greet(name):
#       4     print("Hello, " + name)
# ----> 6 greet(AI)
#
# NameError: name 'AI' is not defined
